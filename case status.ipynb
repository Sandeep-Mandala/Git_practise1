# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"Visadataset.csv")
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
cdf=visa_df['case_status'].value_counts()
values=cdf.values
keys=cdf.keys()
cols=['Labels','Count']
df=pd.DataFrame(zip(keys,values),columns=cols)
df.to_csv('case_status.csv',index=False)

# %%
cdf=visa_df['case_status'].value_counts()
values=cdf.values
keys=cdf.keys()
cols=['Labels','Count']
df=pd.DataFrame(zip(keys,values),columns=cols)
#  df.to_csv('case_status.csv',index=False)
plt.bar('Labels','Count',data=df) # continents u given no of applicants u given but data kidhar hai
# Out:
# <BarContainer object of 2 artists>

# %%
import seaborn as sns
plt.figure(figsize=(8,5))
order_continents=['Asia','Europe','North America','South America','Africa','Oceania']
df=sns.countplot(data=visa_df,x='continent',order=order_continents)
plt.title('Bar Chart')
plt.savefig('continents_bar_chart_using_seaborn.jpg')
plt.show()

# %%
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
import seaborn as sns
plt.figure(figsize=(8,5))
order_continents=visa_df['continent'].value_counts().keys()
df=sns.countplot(data=visa_df,x='continent',order=order_continents)
plt.title('Bar Chart')
plt.savefig('continents_bar_chart_using_seaborn.jpg')
plt.show()

# %%
visa_df=pd.read_csv(r"Visadataset.csv")
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
cat_columns=visa_df.columns

# %%
vdf=cat_columns[1:]
for i in vdf:
    import seaborn as sns
    plt.figure(figsize=(8,5))
    order_continents=visa_df[i].value_counts().keys()
    df=sns.countplot(data=visa_df,x=i,order=order_continents)
    plt.title('Bar Chart')
    plt.savefig(f'{i}_seaborn.jpg')
    plt.show()

# %%
cat_columns=visa_df.columns

# %%
cat_columns[1:]
# Out:
# Index(['continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sande\\OneDrive\\Desktop\\data science\\python\\EDA'

# %%
os.makedirs(name='graphs_seaborn')

# %%
root_directory=os.getcwd()
root_directory

# %%
new_folder='graphs_seaborn'

# %%
new_dir=os.path.join(root_directory,new_folder)
new_dir

# %%
os.makedirs(new_dir)

# %%
try:
    #step-1
    
    import os
    os.getcwd()
    root_directory=os.getcwd()
    root_directory
    
    #step-2
    new_folder='graphs_matpl'
    
    #step-3
    new_dir=os.path.join(root_directory,new_folder)
    new_dir
    
    #step-4
    os.makedirs(new_dir)

except Exception as e:
    print(e)

# %%
os.makedirs(name='graphs_seaborn')

# %%
'''try:
    root_directory=os.getcwd()
    new_folder='experiment'
    new_dir=os.path.join(root_directory,new_folder)
    os.makedirs(new_dir)

except Exception as e:
    print(e)'''

# %%
import seaborn as sns
for i in cat_columns[1:]:
    plt.figure(figsize=(8,5))
    order_continents=visa_df[i].value_counts().keys()
    df=sns.countplot(data=visa_df,x=i,order=order_continents)
    plt.title('Bar Chart')
    plt.savefig(f'{new_dir}\\{i}_seaborn.jpg')
    plt.show()

# %%
try:
    os.getcwd()
    new_dir=os.makedirs(name='graphs_matplotlib')
except Exception as e:
    print(e)

# %%
root_directory=os.getcwd()
new_folder='value_count_df'
dir=os.path.join(root_directory,new_folder)
dir
# Out:
# 'C:\\Users\\sande\\OneDrive\\Desktop\\data science\\python\\EDA\\value_count_df'

# %%
dfs=os.listdir(dir)
dfs
# Out:
# ['case_status.csv',
#  'continent.csv',
#  'education_of_employee.csv',
#  'full_time_position.csv',
#  'has_job_experience.csv',
#  'region_of_employment.csv',
#  'requires_job_training.csv',
#  'unit_of_wage.csv']

# %%
import matplotlib.pyplot as plt
for i in dfs:
    df=pd.read_csv(f"{dir}\\{i}")
    plt.bar('Labels','Count',data=df)  # continents u given no of applicants u given but data kidhar hai
    plt.title("Bar chart")
    plt.xlabel("Lables")
    plt.ylabel("Count")
    plt.savefig(f"{dir}\\{i}_matplotlib.jpg")
    plt.show()

# %%
df=pd.read_csv(f"{dir}\\{'continent.csv'}")
plt.bar('Labels','Count',width=0.5,data=df)  
plt.figure(figsize=(1,1))
plt.show()

# %%
pd.read_csv(f"{dir}\\case_status.csv")
# Out:
#       Labels  Count
# 0  Certified  17018
# 1     Denied   8462

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()

# %%
plt.subplot(3,3,1)
plt.subplot(3,3,2)
plt.subplot(3,3,3)
plt.subplot(3,3,4)
plt.subplot(3,3,5)
plt.subplot(3,3,6)
plt.subplot(3,3,7)
plt.subplot(3,3,8)
plt.subplot(3,3,9)
plt.show()

# %%
plt.subplot(2,1,1)
plt.subplot(2,1,2)
# Out:
# <Axes: >

# %%
for i in range(1,3):
    plt.subplot(1,2,i)

# %%
for i in range(1,9):
    plt.subplot(3,3,i)

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
plt.figure(figsize=(8,1))
plt.subplot(1,2,1)
sns.countplot(x='continent',data=visa_df)
plt.subplot(1,2,2)
sns.countplot(x='case_status',data=visa_df)
# Out:
# <Axes: xlabel='case_status', ylabel='count'>

# %%
types=dict(visa_df.dtypes)
cat_columns=[key for key,value in types.items() if value=='object']
num_columns=[key for key,value in types.items() if value!='object']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 types=dict(visa_df.dtypes)
#       2 cat_columns=[key for key,value in types.items() if value=='object']
#       3 num_columns=[key for key,value in types.items() if value!='object']
#
# NameError: name 'visa_df' is not defined

# %%
cat_columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cat_columns
#
# NameError: name 'cat_columns' is not defined

# %%
plt.figure(figsize=(14,10))
plt.subplot(2,2,1)
sns.countplot(x='continent',data=visa_df)
plt.title('continent_bar_chart')
plt.subplot(2,2,2)
sns.countplot(x='has_job_experience',data=visa_df)
plt.title('has_job_experiencet_bar_chart')
plt.subplot(2,2,3)
sns.countplot(x='requires_job_training',data=visa_df)
plt.title('requires_job_training_bar_chart')
plt.subplot(2,2,4)
sns.countplot(x='case_status',data=visa_df)
plt.title('case_status_bar_chart')
plt.show()

# %%
cat_columns=visa_df.columns

# %%
cols=cat_columns[1:]
for i in range(len(cols)):
    plt.subplot(3,3,i+1)
    plt.figure(figsize=(14,10))
    sns.countplot(x=cols[i],data=visa_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 cols=cat_columns[1:]
#       2 for i in range(len(cols)):
# ----> 3     plt.subplot(3,3,i+1)
#       4     plt.figure(figsize=(14,10))
#       5     sns.countplot(x=cols[i],data=visa_df)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1425, in subplot(*args, **kwargs)
#    1422 fig = gcf()
#    1424 # First, search for an existing subplot with a matching spec.
# -> 1425 key = SubplotSpec._from_subplot_args(fig, args)
#    1427 for ax in fig.axes:
#    1428     # If we found an Axes at the position, we can re-use it if the user passed no
#    1429     # kwargs or if the axes class and kwargs are identical.
#    1430     if (ax.get_subplotspec() == key
#    1431         and (kwargs == {}
#    1432              or (ax._projection_init
# ...

# %%
cols=visa_df.columns[1:]
cols
# Out:
# Index(['continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cat_columns[1:]
# Out:
# Index(['continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')
